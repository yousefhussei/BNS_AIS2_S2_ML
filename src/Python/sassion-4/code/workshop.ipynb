# %%
def factorial(num:int)-> int:
    ''' 
    Calculate n! useing recursion

    args:
        num(int): user input tha int number

    return:
        num(int):return the factorial

    '''
    if num == 0:
        return 1
    return num * factorial(num-1)

# %%
factorial(5)
# Out:
# 120

# %%
def is_prime(num:int)-> bool:
    '''
    Check for the number is prime or not

    args:
        num(int): number for check

    return:
        bool: True if the number is prime, False otherwise
    '''
    if num < 2:
        return False
        return False
    for i in range(2,num):
        if num % i == 0:
            return False
    return True

# %%
is_prime(17)
# Out:
# True

# %%
def common_divisor(num1:int,num2:int)-> list[int]:

    '''
    this function help to calc the common divisor

    args:
        num1(int): first number
        num2(int): second number

    return:
        list[int]: return the common divisor of two numbers

    '''
    limit = min(num1,num2)
    divisors = []
    for divisor in range(1, limit+1):
        if num1 % divisor == 0 and num2 % divisor == 0:
            divisors.append(divisor)
    return divisors

# %%
common_divisor(10,20)
# Out:
# [1, 2, 5, 10]

# %%
def reverse_text(s:str)-> str:
    '''
    Reverse the order of words in a string.

    args:
        s(str): The input string.

    return:
        str: The string with words in reverse order.
    '''
    if not isinstance(s, str):
        raise ValueError("Input must be a string.")
    lst = s.split()
    print(lst)
    new_lst = lst[::-1]
    print(new_lst)

# %%
user_input = input("Enter a string: ")
reverse_text(user_input)
# Out:
# ['yousevf', 'gfdg']
# ['gfdg', 'yousevf']

# %%
def reverse_word(s:str)-> str:

    return ' '.join(s.split()[::-1])

# %%
reverse_word("hi depi")
# Out:
# 'depi hi'

# %%
import random
import string
import secrets
def genarate_pass(leangh:int)->str:
    '''
    this function

    args:

    '''
    character = (string.ascii_letters +
                string.digits +
                string.punctuation)
    password = ""


    return ''.join(secrets.choice(character)for _ in range(leangh))

# %%
genarate_pass(8)
# Out:
# '?+(lpZ12'

# %%
def count_word():
    words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
    uniqus_words = set(words)

    for word in uniqus_words:
        print( f"{word}: {words.count(word)}")

# %%
count_word()
# Out:
# Welcome: 1
# No: 3
# Ali: 4
# Hi: 2

# %%
# Predefined responses
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

def main_bot():
    print("chatbot: Hi How can i assust you ?")

    while True:
        user_input = input("user:   ").lower()
        response = get_response(user_input)
        print("chatpot:",response)

        if user_input == "Goodbye":
            break

# %%
get_response("hello")
# Out:
# 'Greetings!'
