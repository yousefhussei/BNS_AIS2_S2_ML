# %% [markdown]
# # python basic

# %%
x = 20
print("my age is", x)
# Out:
# my age is 20

# %%
# Built-in function
hex(id(20))
print(x)
# Out:
# 20

# %%
''' 
i'm yousef hussein,
 a software engineer and a python developer.

'''
# Out:
# " \ni'm yousef hussein,\n a software engineer and a python developer.\n\n"

# %%
# variable 
x = 20
y = 30.5
a = ("hello world")
s = True

print(type(x))
print(type(y))
print(type(a))
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# formatting string
name = "yousef hussein"
age = 20
print("my name is {name} and my age is {age}".format(name=name, age=age))
print("my name is {0} and my age is {1}".format(name, age))
print("my name is {} and my age is {}".format(name, age))
print(f"my name is {name} and my age is {age}")
# Out:
# my name is yousef hussein and my age is 20
# my name is yousef hussein and my age is 20
# my name is yousef hussein and my age is 20
# my name is yousef hussein and my age is 20

# %%
# list tuple  dict set

list_1 = [1, 2, 3, 4, 5]
print(type(list_1))

tuple_1 = (1, 2, 3, 4, 5)
print(type(tuple_1))

dict_1 = {
            "k1": 1,
            "k2": 2,
            "k3": 3
            }
print(type(dict_1))

set_1 = {1, 2, 3, 4, 5}
print(type(set_1))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>

# %%
#index
name = "yousef"
name[-1]
# Out:
# 'f'

# %%
sent = "Depi for machine learning"
sent[-8:-1:1]
# Out:
# 'learnin'

# %%
name = "depi in machine learning for everyone"
capital = (name.upper())
capital
# Out:
# 'DEPI IN MACHINE LEARNING FOR EVERYONE'

# %%
lower_case = (capital.lower())
lower_case
# Out:
# 'depi in machine learning for everyone'

# %%
name = "depi for machine learning"
print (name.replace("machine", "deep"))
# Out:
# depi for deep learning

# %%
name = "Deep learning for everyone"
name.capitalize()
# Out:
# 'Deep learning for everyone'

# %%
name = "depi for common track"
name.title()
# Out:
# 'Depi For Common Track'

# %%
name = "depi for every one need to learn and depi help students "
print(name.count("depi"))
# Out:
# 2

# %%
name = " i need your help for explain the deep learning optimization algrithms"
x = name.split()
print(type(x))
# Out:
# <class 'list'>

# %%
new_x = " ".join(x)
print(new_x)
# Out:
# i need your help for explain the deep learning optimization algrithms

# %%
name = "depi for machine learning"
name.startswith("depi")
# Out:
# True

# %%
print("depi and nti help \"students\" for ml")
# Out:
# depi and nti help "students" for ml

# %%
print("depi and nti help \t students for ml")
# Out:
# depi and nti help 	 students for ml

# %%
name = " i need your help for explain the deep learning optimization algrithms"
name.strip()
# Out:
# 'i need your help for explain the deep learning optimization algrithms'

# %%
name.isalpha()
# Out:
# False
