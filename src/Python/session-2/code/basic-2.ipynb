# %%
list_1 = [1, 2, 3, 4, "depi","learning",True,[1,2,3,"True",["ml","DL","GenAI"]]]

# %%
# print(type(list_1))

list_1[7][4][1] = "Deep Learning"

# %%
list_1
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'True', ['ml', 'Deep Learning', 'GenAI']]]

# %%
y = list("yousef")

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
# append function

list_one = ["depi","lenarning","ml"]

list_one.append("Deep Learning")
print(list_one)
# Out:
# ['depi', 'lenarning', 'ml', 'Deep Learning']

# %%
# insert function

list_one = ["depi","lenarning","ml"]

list_one.insert(1,"data science")
print(list_one)
# Out:
# ['depi', 'data science', 'lenarning', 'ml']

# %%
# extend function

list_one = ["depi","lenarning","ml"]
list_one.extend(["Deep"])
print(list_one)
# Out:
# ['depi', 'lenarning', 'ml', 'Deep']

# %%
list_one = ["depi","lenarning","ml"]

new_list = list_one + ["Deep Learning","data science"]
print(list_one)
print(new_list)
# Out:
# ['depi', 'lenarning', 'ml']
# ['depi', 'lenarning', 'ml', 'Deep Learning', 'data science']

# %%
# remove function

list_one = ["depi","lenarning","ml"]
list_one.remove("lenarning")
print(list_one)
# Out:
# ['depi', 'ml']

# %%
# pop function

list_one = ["depi","lenarning","ml"]
print(list_one)
list_one.pop()
# Out:
# ['depi', 'lenarning', 'ml']
# 'ml'

# %%
list_1 = ["depi","nti","iti"]
new_list = []

task_1 = list_1.pop()
new_list.append(task_1)

print(list_1)
print(new_list)
# Out:
# ['depi', 'nti']
# ['iti']

# %%
#del function

list_one = ["depi","lenarning","ml"]
del list_one[:]
list_one
# Out:
# []

# %%
list_one.clear()
list_one
# Out:
# []

# %%
input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

item = input("enter item: ")

input_list.remove(item)

print(input_list)
# Out:
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
list_1 = [1,2,3,4]
list_new = list_1.index(3)
# Out:
# 2

# %%
list_1 = [1,2,3,4,2,2]
list_new = list_1.count(2)
print(list_new)
# Out:
# 3

# %%
list_1 = [200,100,250,10,70,30]
list_1.sort()
print(list_1)
# Out:
# [10, 30, 70, 100, 200, 250]

# %%
new_sorted_list = sorted(list_1)
print(new_sorted_list)
# Out:
# [10, 30, 70, 100, 200, 250]

# %%
tuple_one = ("depi","learning","ml")
tuple_one[0]
# Out:
# 'depi'

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
set_one = {"depi","learning"}
set_one[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 set_one = {"depi","learning"}
# ----> 2 set_one[0]
#
# TypeError: 'set' object is not subscriptable

# %%
set_1 = "yousef"
y = set(set_1)
y
# Out:
# {'e', 'f', 'o', 's', 'u', 'y'}

# %%
set_one = {3,4,4,1,5,8,2}
print(set_one)
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
set_one.add(10)
print(set_one)
# Out:
# {1, 2, 3, 4, 5, 8, 10}

# %%
set_one.remove(8)
print(set_one)
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
data1 = {
    101,
    102,
    103,
    104
}
data2 = {
    103,
    104,
    105,
    106
}

# %%
print(data1.intersection(data2))
# Out:
# {104, 103}

# %%
print(data1.union(data2))
# Out:
# {101, 102, 103, 104, 105, 106}

# %%
words = ["python","ai","python","ai"]
unique_words = list(set(words))
print(unique_words)
# Out:
# ['python', 'ai']

# %%
data1 = {"k1":100,"k2":200,"k3":[1,2,3]}
print(type(data1))
# Out:
# <class 'dict'>

# %%
data1["k1"] = "Depi"
print(data1)
# Out:
# {'k1': 'Depi', 'k2': 200, 'k3': [1, 2, 3]}

# %%
chatbot = {
    "hello": "Hello! How can I help you today?",
    "python": "Python is programming language!",
    "ai"    : "enable machine learning to learn from data"
}
print(chatbot.keys())
# Out:
# dict_keys(['hello', 'python', 'ai'])

# %%
questions = input("question: ").lower()

print(chatbot.get(questions, "I don't understand that question."))
# Out:
# I don't understand that question.

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a
