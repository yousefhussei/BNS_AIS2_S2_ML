# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# %%
data = pd.read_csv('Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.figure(figsize=(3, 3))
sns.pairplot(data, x_vars='YearsExperience', y_vars='Salary', size=3, kind='scatter')
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title('Years vs Salary')
plt.show()
# Out:
# c:\Users\New Star Computer 26\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, 1]
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=20)

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
lin_reg.coef_
y_hat_train = lin_reg.predict(x_train)

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, y_hat_train, color='blue')
plt.title('linear Regression')
plt.xlabel('Years')
plt.ylabel('Salary')
plt.show()

# %%
y_hat_test = lin_reg.predict(x_test)

# %%
print("linear regression eval")
print("="* 40)
print("Train...............Eval")
print("MSE:", mean_squared_error(y_train, y_hat_train))
print("RMSE:", root_mean_squared_error(y_train, y_hat_train))
print("R2:", r2_score(y_train, y_hat_train))
print("Test................Eval")
print("MSE:", mean_squared_error(y_test, y_hat_test))
print("RMSE:", root_mean_squared_error(y_test, y_hat_test))
print("R2:", r2_score(y_test, y_hat_test))
# Out:
# linear regression eval
# ========================================
# Train...............Eval
# MSE: 29478554.345388774
# RMSE: 5429.415654137079
# R2: 0.9568762774706462
# Test................Eval
# MSE: 40458438.741648726
# RMSE: 6360.6948316712005
# R2: 0.9441299149555877
